# %%
import math
math.sqrt(25)
math.pi
# Out:
# 3.141592653589793

# %%
import numpy
import math
from scipy import stats
from numpy import random
import numpy as np
# uniform random numbers in [0,1]
dataOne = random.rand(5,5)
np.mean(dataOne)
# Out:
# 0.5301610477941957

# %%
print('I Love data Science')
# Out:
# I Love data Science

# %%
x=25
y='I Love data Science'
print(y)
# Out:
# I Love data Science

# %%
x=25
type(x)
# Out:
# int

# %%
x=25.0
type(x)
# Out:
# float

# %%
varOne=25
# add '' to varOne to turn it into a string and varThree will run
varTwo='Hello'
varThree= varOne + varTwo
print(varThree)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-c98d4c46a566> in <module>
#       2 # add '' to varOne to turn it into a string and varThree will run
#       3 varTwo='Hello'
# ----> 4 varThree= varOne + varTwo
#       5 print(varThree)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
listone=[1,2,3,4]
print(listone[1:3])
# Out:
# [2, 3]

# %%
tel={'jack':4098,'sape':4139}
tel['jack']
# Out:
# 4098

# %%
import math
practice={'jack':1234, 'jill':1235, 'hill':1236, 'bill':1237, 'shill':1238}
x=math.sqrt(practice['jack'])
print(x)
y=math.floor(practice['jill'])
print(y)
z=math.fabs(practice['hill'])
print(z)
# Out:
# 35.12833614050059
# 1235
# 1236.0

# %%
import pandas as pd
pd.read_csv("C2.T31output.csv")
# Out:
#     Unnamed: 0       ProductType  ProductNum    Price  x5StarReviews  \
# 0            1                PC         171   699.00             96
# 1            2                PC         172   860.00             51
# 2            3            Laptop         173  1199.00             74
# 3            4            Laptop         175  1199.00              7
# 4            5            Laptop         176  1999.00              1
# 5            6           Netbook         178   399.99             19
# 6            7           Netbook         180   329.00            312
# 7            8           Netbook         181   439.00             23
# 8            9           Netbook         183   330.00              3
# 9           10            Tablet         186   629.00            296
# 10          11            Tablet         187   199.00            943
# 11          12        Smartphone         193   199.00             99
# 12          13        Smartphone         194    49.00            100
# 13          14        Smartphone         195   149.00             42
# 14          15        Smartphone         196   300.00             50
# 15          16       GameConsole         199   249.99            462
# 16          17           Display         201   140.00              4
# 17          18       Accessories         301    20.99             30
# 18          19       Accessories         302     8.50             25
# 19          20          Software         303    70.99             29
# 20          21           Printer         304   199.99             88
# 21          22   PrinterSupplies         305    20.99              5
# 22          23  ExtendedWarranty         306    99.99              0
# 23          24       GameConsole         307   425.00           1525
#
#     x4StarReviews  x3StarReviews  x2StarReviews  x1StarReviews  \
# 0              26             14             14             25
# 1              11             10             10             21
# 2              10              3              3             11
# 3               2              1              1              1
# 4               1              1              3              0
# 5               8              4              1             10
# 6             112             28             31             47
# 7              18              7             22             18
# 8               4              0              1              0
# 9              66             30             21             36
# 10            437            224            160            247
# 11             26             12             16             35
# 12             26             37             33             48
# 13              8              4              4              9
# 14             19             13             20             22
# 15             97             25             17             58
# 16              0              0              0              2
# 17              1              5              0              0
# 18              2              2              4             15
# 19             18              3              1              8
# 20              8              3              1              3
# 21              0              0              0              0
# 22              1              1              1              1
# 23            252             99             56             45
#
#     PositiveServiceReview  NegativeServiceReview  Recommendproduct  \
# 0                      12                      3               0.7
# 1                       7                      5               0.6
# 2                      11                      5               0.8
# 3                       2                      1               0.6
# 4                       0                      1               0.3
# 5                       2                      4               0.6
# 6                      28                     16               0.7
# 7                       5                     16               0.4
# 8                       1                      0               0.7
# 9                      28                      9               0.8
# 10                     90                     23               0.8
# 11                      8                      6               0.4
# 12                     14                      6               0.6
# 13                      4                      1               0.7
# 14                      5                      7               0.6
# 15                     32                     12               0.8
# 16                      1                      1               0.7
# 17                      2                      0               0.9
# 18                      2                      1               0.5
# 19                      4                      2               0.8
# 20                      5                      1               0.8
# 21                      1                      0               1.0
# 22                      0                      3               0.4
# 23                     59                     13               0.9
#
#     BestSellersRank  ShippingWeight  ProductDepth  ProductWidth  \
# 0              2498           19.90         20.63         19.25
# 1               490           27.00         21.89         27.01
# 2               111            6.60          8.94         12.80
# 3              4446           13.00         16.30         10.80
# 4              2820           11.60         16.81         10.90
# 5              4140            5.80          8.43         11.42
# 6              2699            4.60         10.17          7.28
# 7              1704            4.80          8.00         11.70
# 8              5128            4.30          7.40         10.40
# 9                34            3.00          7.31          9.50
# 10                1            0.90          5.40          7.60
# 11             1277            0.90          2.70          5.20
# 12            16966            0.70          2.67          5.33
# 13             6316            0.80          2.70          5.30
# 14            44465            0.90          2.60          5.00
# 15              115            8.40          6.20         13.20
# 16              324            8.90         13.60         17.60
# 17               18            0.75         10.70         13.10
# 18               38            1.00          7.30          7.00
# 19              122            0.20          8.00          7.00
# 20               40           42.00         17.30         23.50
# 21             1011            1.00          4.70          2.90
# 22                5            0.20          0.00          0.00
# 23              215           20.00          8.50          6.00
#
#     ProductHeight  ProfitMargin  Volume  predictions
# 0            8.39          0.25       0   330.504862
# 1            9.13          0.20       0   203.017966
# 2            0.68          0.10       0   191.163319
# 3            1.40          0.15       0   133.990440
# 4            0.88          0.23       0   154.364853
# 5            1.20          0.08       0   110.571719
# 6            0.95          0.09       0   971.115180
# 7            1.50          0.11       0   186.654141
# 8            0.97          0.09       0    74.214157
# 9            0.37          0.10       0   636.618819
# 10           0.40          0.20       0  3550.314445
# 11           0.40          0.11       0   238.094578
# 12           0.37          0.12       0   253.418936
# 13           0.40          0.15       0    92.669807
# 14           0.40          0.11       0   178.773985
# 15          13.20          0.09       0   846.195758
# 16           7.30          0.05       0    53.252868
# 17           0.60          0.05       0    61.057987
# 18           1.60          0.10       0    57.711752
# 19           1.00          0.20       0   188.236746
# 20          25.80          0.90       0   126.071114
# 21           6.30          0.30       0    31.083162
# 22           0.00          0.40       0    21.576353
# 23           1.75          0.18       0  2112.395815
